# %%
import pandas as pd
df = pd.read_csv('HMCTS_MI_output_accessible_June_25_final.csv',encoding='latin-1')

# %%
df.style.background_gradient(cmap='RdPu')
# Out:
# <style type="text/css">
# #T_9a32f_row0_col1, #T_9a32f_row8_col60 {
#   background-color: #fde3e0;
#   color: #000000;
# }
# ...

# %%
import pandas as pd
df = pd.read_csv('HMCTS_MI_output_accessible_June_25_final.csv',encoding='latin-1')
columnToDelete = ['Month']
df1 = df.drop(columnToDelete,axis=1)

# %%
df1.corr(method='pearson').style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# ...
